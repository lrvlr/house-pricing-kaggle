# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

import ipynb.fs.full.plotFunctions as myplt
import ipynb.fs.full.preprocessFunctions as pp
import ipynb.fs.full.tableFunctions as tab

plt.style.use('Solarize_Light2')

# %%
pd.options.display.max_rows = 4000 #this is so that the notebook won't truncate results

# %%
test = pd.read_csv("test.csv", index_col="Id")
train = pd.read_csv("train.csv", index_col="Id")

# %%
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# # Data types
#
# First we will check if all data types were loaded correctly and correct the ones that weren't. By taking a look at the metadata we expect some features to be categorical and some others to be numerical.

# %%
meta_cat = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
                'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 
                'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
                'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
                'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
                'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition', 'LandSlope']

meta_num = ['SalePrice','LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtUnfSF',
            'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
            'FullBath', 'HalfBath', 'Bedroom', 'Kitchen', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
            'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
            'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'BsmtFinSF1', 'BsmtFinSF2']

# %%
# get the actual numerical columns and object columns loaded
numbers = train.select_dtypes(include='number').columns
objects = train.select_dtypes(include='object').columns

# get columns that were loaded as objects but should have been numerical
print('The following columns should have been numerical, but were not loaded as such:')
print([num for num in meta_num if num not in numbers])

# get columns that were loaded as numbers but should have been objects
print('The following columns were loaded as numbers but are categorical or not listed:')
print([num for num in numbers if num not in meta_num])

# get columns that should be in the dataframe but are not.
print('The following columns were not in the dataframe:')
print([col for col in meta_cat + meta_num if col not in train.columns])

# get columns that are in the dataframe but shouldn't.
print('The following columns were not listed in metadata:')
print([col for col in train.columns if col not in meta_cat + meta_num])
# Out:
# The following columns should have been numerical, but were not loaded as such:
# ['Bedroom', 'Kitchen']
# The following columns were loaded as numbers but are categorical or not listed:
# ['MSSubClass', 'OverallQual', 'OverallCond', 'BedroomAbvGr', 'KitchenAbvGr']
# The following columns were not in the dataframe:
# ['Bedroom', 'Kitchen']
# The following columns were not listed in metadata:
# ['BedroomAbvGr', 'KitchenAbvGr']

# %% [markdown]
# We can see here that some categorical values are numbers: 'MSSubClass', 'OverallQual', 'OverallCond', which will do for later so we'll keep them that way.
# On the other side, 'Bedroom' and 'Kitchen' seem to be named as 'BedroomAbvGr' and 'KitchenAbvGr', we'll rename them.

# %%
pp.renameCols(train)

# %% [markdown]
# # Target Feature
#
# For starters, we cannot use rows with missing target to train any model. So we'll check this. On the other hand let's take a look at the target distribution.

# %%
missing_target = train[train.SalePrice.isna()]
len(missing_target)
# Out:
# 0

# %% [markdown]
# We have no missing targets.

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Let's get a visual idea of this distribution

# %%
myplt.pltHist(train, 'SalePrice', 20, 'Price Range', 'Number of properties')
# Out:
# <AxesSubplot:title={'center':'Histogram of SalePrice'}, xlabel='Number of properties', ylabel='Price Range'>

# %% [markdown]
# We can see that the distribution is skewed: ” In probability theory and statistics, skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.” We want this metric to have a value close to 0.

# %%
train['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %% [markdown]
# We are clearly far away from this. We'll take the log(SalePrice) instead to see if we can correct this

# %%
train['SalePrice'] = np.log(train['SalePrice'])
train['SalePrice'].skew()
# Out:
# 0.12133506220520406

# %%
myplt.pltHist(train, 'SalePrice', 20, 'Price Range', 'Number of properties')
# Out:
# <AxesSubplot:title={'center':'Histogram of SalePrice'}, xlabel='Number of properties', ylabel='Price Range'>

# %% [markdown]
# Another characteristic we are interested in is kurtosis: "Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers. Data sets with low kurtosis tend to have light tails, or lack of outliers. A uniform distribution would be the extreme case."

# %%
train['SalePrice'].kurt()
# Out:
# 0.8095319958036296

# %% [markdown]
# ## Numerical features

# %%
print('We have {} numerical features'.format(len(meta_num)-1))
# Out:
# We have 33 numerical features

# %% [markdown]
# About these features we would like to know a series of characteristics such as how many distinct values, missing values, its skewness and kurtosis, its correlation to SalePrice. Mean, std, quantiles, max and minimum values.

# %%
df_numInfo = tab.numTable(train[meta_num], 'SalePrice')
df_numInfo.style.background_gradient(subset=['Corr'])
# Out:
# <style  type="text/css" >
# #T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col13{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col13{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row2_col13{
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row3_col13{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row4_col13{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row5_col13{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row6_col13{
#             background-color:  #2d8abd;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row7_col13{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row8_col13{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row9_col13{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row10_col13{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row11_col13{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row12_col13{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row13_col13{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row14_col13{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row15_col13{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row16_col13,#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row17_col13{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row18_col13{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row19_col13{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row20_col13{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row21_col13{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row22_col13{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row23_col13{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row24_col13{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row25_col13,#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row26_col13{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row27_col13{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row28_col13{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row29_col13{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row30_col13,#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row31_col13{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row32_col13,#T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row33_col13{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >Min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >Max</th>        <th class="col_heading level0 col8" >Skew</th>        <th class="col_heading level0 col9" >Kurt</th>        <th class="col_heading level0 col10" >% Missing</th>        <th class="col_heading level0 col11" >% Zero</th>        <th class="col_heading level0 col12" >Nuniques</th>        <th class="col_heading level0 col13" >Corr</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11level0_row0" class="row_heading level0 row0" >SalePrice</th>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col0" class="data row0 col0" >1460.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col1" class="data row0 col1" >12.024051</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col2" class="data row0 col2" >0.399452</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col3" class="data row0 col3" >10.460242</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col4" class="data row0 col4" >11.775097</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col5" class="data row0 col5" >12.001505</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col6" class="data row0 col6" >12.273731</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col7" class="data row0 col7" >13.534473</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col8" class="data row0 col8" >0.121335</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col9" class="data row0 col9" >0.809532</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col10" class="data row0 col10" >0.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col11" class="data row0 col11" >0.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col12" class="data row0 col12" >663</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row0_col13" class="data row0 col13" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11level0_row1" class="row_heading level0 row1" >GrLivArea</th>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col0" class="data row1 col0" >1460.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col1" class="data row1 col1" >1515.463699</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col2" class="data row1 col2" >525.480383</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col3" class="data row1 col3" >334.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col4" class="data row1 col4" >1129.500000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col5" class="data row1 col5" >1464.000000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col6" class="data row1 col6" >1776.750000</td>
#                         <td id="T_af4a749e_ebba_11ea_a5c5_fbe62726ba11row1_col7" class="data row1 col7" >5642.000000</td>

# %% [markdown]
# From this table we can begin to make some decisions:
#
# The following features have low correlation, are highly skewed and most of its values are zero, so they don't seem to be good choices for prediction:
#
# * EnclosedPorch
# * LowQualFinSF
# * MiscVal
# * BsmtHalfBath
# * BsmtFinSF2
# * 3SsnPorch
# * Pool Area
# * ScreenPorch
#
# --
#
# * Kitchen is still highly skewed and low correlated so we will dismiss it also
#
# * MoSold and YrSold have low correlation although one would tend to think that this is info one gets after already having a defined price. May be one interesting value would be the difference in years between the Year the property was built or remodeled and the Year it was sold.
#
#
# **The good ones**
#
# These features have good correlation and nice skew values:
#
# * GarageCars
# * GarageArea
# * FullBath
# * YearBuilt
# * YearRemodAdd
# * GarageYrBuilt
# * TotRmsAvbGrd
# * FirePlaces
# * 2ndFlrSF
#
# Good correlation:
#
# * HalfBath
# * BsmtFullBath
# * BsmtUnfSF
# * Bedroom
#
#
# **The ones to work with**
#
# These have great correlation but are highly skewed
#
# * GrLivArea
# * TotalBsmtSF
# * 1stFlrSF
#
# These have good correlation and highly skewed
#
# * MasVnrArea
# * BsmtFinSF1
# * LotFrontage
# * WoodDeckSF
# * OpenPorchSF
# * LotArea

# %% [markdown]
# Let's keep track of the features we will dismiss for prediction, and take a visual look at the remaining ones

# %%
corr_idx = list(df_numInfo.index)

# %%
#We'll keep track of the features we'll dismiss in a list
dismiss = ['EnclosedPorch', 'LowQualFinSF', 'MiscVal', 'BsmtHalfBath', 'BsmtFinSF2', '3SsnPorch', 'Pool Area', 'ScreenPorch', 'Kitchen']

num = [col for col in corr_idx if col not in dismiss]
num.remove('SalePrice')

fig_numericals = myplt.plotNumBoxList(train, num)

# %% [markdown]
# ### Possible Outliers
#
# GarageCars, YearBuilt, TotRmsAbvGrd, Fireplaces, 2ndFlrSF, BsmtFullBath, BsmtUnfSF and Bedroom all seem to have possible outliers. Let's take a deep look on them

# %%
fig_gc = myplt.plotRegRes(train, 'GarageCars', 'SalePrice')

# %%
# YearBuilt feature seems better fitted by a 2nd order polynomial
fig_gc = myplt.plotRegRes(train, 'YearBuilt', 'SalePrice', 2)

# %%
fig_gc = myplt.plotRegRes(train, 'TotRmsAbvGrd', 'SalePrice')

# %%
fig_gc = myplt.plotRegRes(train, 'Fireplaces', 'SalePrice')

# %%
fig_gc = myplt.plotRegRes(train, '2ndFlrSF', 'SalePrice', 2)

# %%
fig_gc = myplt.plotRegRes(train, 'BsmtFullBath', 'SalePrice')

# %%
fig_gc = myplt.plotRegRes(train, 'BsmtUnfSF', 'SalePrice', 2)

# %% [markdown]
# fig_gc = myplt.plotRegRes(train, 'Bedroom', 'SalePrice')

# %%
pd.concat([train[train['TotRmsAbvGrd'] == 14], train[train['Bedroom'] == 8], train[train['BsmtFullBath'] == 3]], axis=0)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 636         190       RH         60.0    10896   Pave  Pave      Reg
# 636         190       RH         60.0    10896   Pave  Pave      Reg
# 739          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 636         Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 636         Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 739         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 636       0      3    2007        WD        Abnorml  12.206073
# 636       0      3    2007        WD        Abnorml  12.206073
# 739       0      3    2009        WD         Alloca  12.095141
#
# [3 rows x 80 columns]

# %% [markdown]
# ### The skewed ones

# %% [markdown]
# TotalBsmtSF has zero values, so we can't calculate log on it just as it is, let's take a deeper look

# %%
fig_tbsf = myplt.plotRegRes(train, 'TotalBsmtSF', 'SalePrice')

# %%
#We have a very clear outlier
train[train['TotalBsmtSF']> 6000]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...      480     Gd   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1299       0      1    2008       New        Partial  11.982929
#
# [1 rows x 80 columns]

# %% [markdown]
# We will remove this outlier and keep track of removed outliers in a list.

# %%
outliers = list(train[train['TotalBsmtSF'] > 6000].index)
train = train[train['TotalBsmtSF'] < 6000]
outliers
# Out:
# [1299]

# %%
train['TotalBsmtSF'].skew()
# Out:
# 0.5736369416201317

# %%
train['TotalBsmtSF'].kurt()
# Out:
# 2.0290806702986632

# %% [markdown]
# As we can see, just by eliminating this outlier we have achieved the desired values for skew and kurt. Let's see if this has made any change on the other skewed variables

# %%
print(train['1stFlrSF'].skew())
fig_glva = myplt.plotRegRes(train, '1stFlrSF', 'SalePrice', 2)
# Out:
# 0.9524102073822629

# %%
#We still seem to have a few outliers
train[train['1stFlrSF']> 2700]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 497           20       RL          NaN    12692   Pave   NaN      IR1
# 524           60       RL        130.0    40094   Pave   NaN      IR1
# 1025          20       RL          NaN    15498   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 497          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 524          Bnk    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1025         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 497        0      5    2007        WD         Normal  12.971540
# 524        0     10    2007       New        Partial  12.126759
# 1025       0      5    2008       COD        Abnorml  12.567237
#
# [3 rows x 80 columns]

# %% [markdown]
# Skewness is better but still not quite the value we'd like. We will eliminate index 524 since this property seems to be an outlier in several features.

# %%
train.drop(index=[524], inplace=True)
outliers.append(524)

# %%
print(train['GrLivArea'].skew())
fig_glva = myplt.plotRegRes(train, 'GrLivArea', 'SalePrice', 1)
# Out:
# 1.0109917025385513

# %% [markdown]
# GrLivArea is still lightly skewed, but this could be fixed by scaling the data later, so we'll work with it.

# %% [markdown]
# #### Highly skewed

# %%
print(train['MasVnrArea'].skew())
fig_mva = myplt.plotRegRes(train, 'MasVnrArea', 'SalePrice')
# Out:
# 2.6877840195436478

# %%
train['MasVnrArea'].fillna(train['MasVnrArea'].mean(), inplace=True)
hist_mva = myplt.pltHist(train, 'MasVnrArea', 20, 'MasVnrArea', '#Properties')

# %% [markdown]
# Almost 60% of the values are zero, so we can't apply log here, we will see what we can do with it later, we'll keep track of it in a skewed list

# %%
skewed=['MasVnrArea']

# %%
print(train['BsmtFinSF1'].skew())
fig_mva = myplt.plotRegRes(train, 'BsmtFinSF1', 'SalePrice')
# Out:
# 0.7647894513451676

# %%
train['BsmtFinSF1'].kurt()
# Out:
# -0.11209773018937907

# %%
print(train['LotFrontage'].skew())
print(train['LotFrontage'].kurt())
fig_mva = myplt.plotRegRes(train, 'LotFrontage', 'SalePrice')
# Out:
# 1.5430431199713504
# 11.52953612041342

# %%
train[train['LotFrontage']>300]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 935          20       RL        313.0    27650   Pave   NaN      IR2
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 935         HLS    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 935       0     11    2008        WD         Normal  12.396693
#
# [1 rows x 80 columns]

# %%
print(train[train['LotFrontage']<300]['LotFrontage'].skew())
print(train[train['LotFrontage']<300]['LotFrontage'].kurt())
# Out:
# 0.6977324167197465
# 2.362427689158153

# %% [markdown]
# We'll drop id 935 as outlier

# %%
train.drop(index=[935], inplace=True)
outliers.append(935)

# %%
print(train['WoodDeckSF'].skew())
print(train['WoodDeckSF'].kurt())
fig_mva = myplt.plotRegRes(train, 'WoodDeckSF', 'SalePrice')
# Out:
# 1.5449166882127714
# 3.0030562206104494

# %%
print(train['OpenPorchSF'].skew())
print(train['OpenPorchSF'].kurt())
fig_mva = myplt.plotRegRes(train, 'OpenPorchSF', 'SalePrice')
# Out:
# 2.339020748971797
# 8.471638101198971

# %%
print(train['LotArea'].skew())
print(train['LotArea'].kurt())
fig_mva = myplt.plotRegRes(train, 'LotArea', 'SalePrice')
# Out:
# 12.609035123571356
# 214.40347884362876

# %% [markdown]
# Lot Area seems to have several outliers, which we are not sure if we want to dismiss yet. But just as it is, Lot Area does not seem to be a great feature for prediction. Let's dismiss it and see what we can do with it later.

# %%
skewed.extend(['LotFrontage', 'WoodDeckSF', 'OpenPorchSF', 'LotArea'])

# %% [markdown]
# ## Categorical Features

# %%
print('We have {} categorical features'.format(len(meta_cat)))
# Out:
# We have 46 categorical features

# %%
df_catInfo = tab.catTable(train[meta_cat])
df_catInfo
# Out:
#               Count Unique      Top  Freq  % Missing
# PoolQC         1457      4      nan  1451  99.588195
# MiscFeature    1457      5      nan  1403  96.293754
# Alley          1457      3      nan  1366  93.754290
# Fence          1457      5      nan  1176  80.713795
# FireplaceQu    1457      6      nan   690  47.357584
# GarageType     1457      7   Attchd   868   5.559369
# GarageQual     1457      6       TA  1308   5.559369
# GarageFinish   1457      4      Unf   605   5.559369
# GarageCond     1457      6       TA  1323   5.559369
# BsmtFinType2   1457      7      Unf  1253   2.608099
# BsmtExposure   1457      5       No   953   2.608099
# BsmtCond       1457      5       TA  1308   2.539465
# BsmtFinType1   1457      7      Unf   430   2.539465
# BsmtQual       1457      5       TA   649   2.539465
# MasVnrType     1457      5     None   863   0.549073
# Electrical     1457      6    SBrkr  1331   0.068634
# PavedDrive     1457      3        Y  1337   0.000000
# SaleType       1457      9       WD  1266   0.000000
# Functional     1457      7      Typ  1357   0.000000
# KitchenQual    1457      4       TA   735   0.000000
# CentralAir     1457      2        Y  1362   0.000000
# HeatingQC      1457      5       Ex   738   0.000000
# Heating        1457      6     GasA  1425   0.000000
# SaleCondition  1457      6   Normal  1197   0.000000
# MSSubClass     1457     15       20   535   0.000000
# MSZoning       1457      5       RL  1148   0.000000
# BldgType       1457      5     1Fam  1217   0.000000
# Street         1457      2     Pave  1451   0.000000
# LotShape       1457      4      Reg   925   0.000000
# LandContour    1457      4      Lvl  1311   0.000000
# Utilities      1457      2   AllPub  1456   0.000000
# LotConfig      1457      5   Inside  1050   0.000000
# Neighborhood   1457     25    NAmes   224   0.000000
# Condition1     1457      9     Norm  1260   0.000000
# Condition2     1457      8     Norm  1443   0.000000
# HouseStyle     1457      8   1Story   725   0.000000
# Foundation     1457      6    PConc   645   0.000000
# OverallQual    1457     10        5   397   0.000000
# OverallCond    1457      9        5   819   0.000000
# RoofStyle      1457      6    Gable  1141   0.000000
# RoofMatl       1457      7  CompShg  1433   0.000000
# Exterior1st    1457     15  VinylSd   515   0.000000
# Exterior2nd    1457     16  VinylSd   504   0.000000
# ExterQual      1457      4       TA   905   0.000000
# ExterCond      1457      5       TA  1279   0.000000
# LandSlope      1457      3      Gtl  1380   0.000000

# %% [markdown]
# We will dismiss the features with more than 80% of missing values:
# * PoolQC
# * MiscFeature
# * Alley
# * Fence

# %%
dismiss.extend(['PoolQC', 'MiscFeature', 'Alley', 'Fence'])

# %% [markdown]
# What about Fireplace quality, we seem to have many missing values, but this could be related to properties not having fireplaces.

# %%
print('Missing values on properties with fireplaces: {}'.format(train[train['Fireplaces']>0]['FireplaceQu'].isna().sum()))
# Out:
# Missing values on properties with fireplaces: 0

# %% [markdown]
# So in this case we could replace nulls with a new category meaning it doesn't apply to this property. On the other hand, let's see how quality of fireplaces relates to price

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='Fireplaces', y='SalePrice', hue=list(train['FireplaceQu']), palette= 'BrBG')
ax.legend(title='FireplaceQu')

# %% [markdown]
# #### Garage Type, Finish, Quality and Condition
# This features also have missing values, is this related to houses with no garages

# %%
train[train['GarageArea'] > 0][['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']].isna().sum()
# Out:
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %% [markdown]
# As we can see here also, missing values imply that the feature does not apply for that property. Once again we can replace missing values with a new label.

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='GarageArea', y='SalePrice', hue=list(train['GarageType']), palette= 'BrBG')
ax.legend(title='GarageType')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='GarageArea', y='SalePrice', hue=list(train['GarageFinish']), palette= 'BrBG')
ax.legend(title='GarageFinish')

# %%
plt.figure(figsize=(10,5))
ax= sns.scatterplot(data=train, x='GarageArea', y='SalePrice', hue=list(train['GarageCond']), palette= 'RdBu_r')
ax.legend(title='GarageCond')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='GarageArea', y='SalePrice', hue=list(train['GarageQual']), palette= 'RdBu_r')
ax.legend(title='GarageQual')

# %% [markdown]
# Both GarageQuality and Condition concentrate more than 80% of the properties on one category: typical/average, and then we have excelent properties with both high and low prices so they might not be great features for prediction. We'll leave them out for the time being.

# %%
dismiss.extend(['GarageQual', 'GarageCond'])

# %% [markdown]
# #### Basement Type 1, 2, Condition, Exposure and Quality
#
# Once again we have missing values here is this related to properties with Total Basement SF = 0

# %%
train[train['TotalBsmtSF'] > 0][['BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtExposure']].isna().sum()
# Out:
# BsmtFinType1    0
# BsmtFinType2    1
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    1
# dtype: int64

# %% [markdown]
# Both Basemnt Exposure and Basment FinType2 have missing values in properties wiht more than 0 SF

# %%
train[(train['TotalBsmtSF'] > 0) & (train['BsmtFinType1'].isna() | train['BsmtExposure'].isna())]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 949          60       RL         65.0    14006   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 949         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 949       0      2    2006        WD         Normal  12.167851
#
# [1 rows x 80 columns]

# %% [markdown]
# It is in fact the same property. We might consider filling this ones with the mean value. The rest with a new label. Or just apply the new label to every property.

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice', hue=list(train['BsmtFinType1']), palette= 'RdBu_r')
ax.legend(title='BsmtFinType1')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice', hue=list(train['BsmtFinType2']), palette= 'RdBu_r')
ax.legend(title='BsmtFinType2')

# %% [markdown]
# We should consider combining both Types in one category

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice', hue=list(train['BsmtQual']), palette= 'RdBu_r')
ax.legend(title='BsmtQual')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice', hue=list(train['BsmtCond']), palette= 'RdBu_r')
ax.legend(title='BsmtCond')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice', hue=list(train['BsmtExposure']), palette= 'RdBu_r')
ax.legend(title='BsmtExposure')

# %% [markdown]
# #### MasVnrType
# Again too many missing values, probably related to MasVnrArea = 0

# %%
train[train['MasVnrArea'] > 0][['MasVnrType']].isna().sum()
# Out:
# MasVnrType    8
# dtype: int64

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='MasVnrArea', y='SalePrice', hue=list(train['MasVnrType']), palette= 'RdBu_r')
ax.legend(title='MasVnrType')

# %% [markdown]
# #### Electrical
# Has a few missing values, we'll impute them with a new label

# %% [markdown]
# #### Lot shape, Land Contour, LotConfig, LandSlope

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='LotArea', y='SalePrice', hue=list(train['LotShape']), palette= 'RdBu_r')
ax.legend(title='LotShape')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='LotArea', y='SalePrice', hue=list(train['LotConfig']), palette= 'RdBu_r')
ax.legend(title='LotConfig')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='LotArea', y='SalePrice', hue=list(train['LandSlope']), palette= 'RdBu_r')
ax.legend(title='LandSlope')

# %%
plt.figure(figsize=(10,5))
ax = sns.scatterplot(data=train, x='LotArea', y='SalePrice', hue=list(train['LandContour']), palette= 'RdBu_r')
ax.legend(title='LandContour')

# %% [markdown]
# **The ammount of categorical features is quite overwhelming. They all seem to add up a little info but I'm not quite sure yet what to do with them. Eventually we will encode them in a numerical way so that we can use them for prediction, may be we could see how this numerical encoding correlates to SalePrice?
# We could also create some bivariates to see if they improve the skewness and correlation of their univariates**

# %%
train['Conditions'] = train['Condition1'] + '-' + train['Condition2']
train['Overall'] = train['OverallQual'].astype(str) + '-' + train['OverallCond'].astype(str)
train['Roof'] = train['RoofStyle'] + '-' + train['RoofMatl']
train['Exterior'] = train['Exterior1st'] + '-' + train['Exterior2nd']
train['External'] = train['ExterQual'] + '-' + train['ExterCond']
train['Basement'] = train['BsmtQual'] + '-' + train['BsmtCond']
train['BasementFin'] = train['BsmtFinType1'] + '-' + train['BsmtFinType2']
train['Garage'] = train['GarageQual'] + '-' + train['GarageCond']
train['GarageTF'] = train['GarageType'] + '-' + train['GarageFinish']
train['HeatingCond'] = train['Heating'] + '-' + train['HeatingQC']
train['Sale'] = train['SaleType'] + '-' + train['SaleCondition']
train['Lot'] = train['LotShape'] + '-' + train['LotConfig']
    
meta_cat.extend(['Conditions', 'Overall', 'Roof', 'Exterior', 'External', 'Basement', 'BasementFin', 'Garage', 'GarageTF', 'HeatingCond', 'Sale', 'Lot'])

# %%
import category_encoders as ce
train[meta_cat].fillna(value='DNA', inplace=True)
cb_enc = ce.CatBoostEncoder(cols=meta_cat)
cb_enc.fit(train[meta_cat], train['SalePrice'])
encoded = pd.concat([cb_enc.transform(train[meta_cat]),train['SalePrice']],axis=1)
encoded.head()
# Out:
# C:\Users\lauri_almadeartista\Miniconda3\envs\py37\lib\site-packages\pandas\core\frame.py:4320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# C:\Users\lauri_almadeartista\Miniconda3\envs\py37\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#     MSSubClass   MSZoning     Street      Alley   LotShape  LandContour  \
# Id
# 1    12.340827  12.085614  12.025225  12.037377  11.936188    12.022695
# 2    12.052092  12.085614  12.025225  12.037377  11.936188    12.022695
# 3    12.340827  12.085614  12.025225  12.037377  12.163253    12.022695
# 4    11.965024  12.085614  12.025225  12.037377  12.163253    12.022695
# 5    12.340827  12.085614  12.025225  12.037377  12.163253    12.022695
#
#     Utilities  LotConfig  Neighborhood  Condition1  ...   Exterior   External  \
# Id                                                  ...
# 1   12.023885  12.001426     12.162715   12.042901  ...  12.211522  12.313264
# 2   12.023885  12.034512     12.317474   11.818838  ...  11.863908  11.843162
# 3   12.023885  12.001426     12.162715   12.042901  ...  12.211522  12.313264
# 4   12.023885  12.027601     12.203141   12.042901  ...  11.834101  11.843162
# 5   12.023885  12.034512     12.660470   12.042901  ...  12.211522  12.313264
#
#      Basement  BasementFin     Garage   GarageTF  HeatingCond       Sale  \
# Id
# 1   12.175649    12.310566  12.074778  12.181838    12.207748  12.007915
# 2   12.175649    11.934184  12.074778  12.181838    12.207748  12.007915
# 3   12.175649    12.310566  12.074778  12.181838    12.207748  12.007915
# 4   12.070981    11.934184  12.074778  11.757858    11.910546  11.788138
# 5   12.175649    12.310566  12.074778  12.181838    12.207748  12.007915
#
#           Lot  SalePrice
# Id
# 1   11.937946  12.247694
# 2   11.980687  12.109011
# 3   12.153408  12.317167
# 4   12.178806  11.849398
# 5   12.080111  12.429216
#
# [5 rows x 59 columns]

# %%
df_numCatInfo = tab.numTable(encoded, 'SalePrice')
df_numCatInfo.style.background_gradient(subset=['Corr'])
# Out:
# <style  type="text/css" >
# #T_bfa402ca_ebba_11ea_b282_fbe62726ba11row0_col13{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row1_col13{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row2_col13{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row3_col13{
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row4_col13{
#             background-color:  #1e80b8;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row5_col13{
#             background-color:  #2081b9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row6_col13{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row7_col13{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row8_col13{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row9_col13{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row10_col13{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row11_col13{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row12_col13{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row13_col13{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row14_col13{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row15_col13{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row16_col13{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row17_col13{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row18_col13{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row19_col13{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row20_col13{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row21_col13{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row22_col13{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row23_col13{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row24_col13{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row25_col13{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row26_col13{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row27_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row28_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row29_col13{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row30_col13{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row31_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row32_col13{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row33_col13{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row34_col13{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row35_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row36_col13{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row37_col13{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row38_col13{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row39_col13{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row40_col13{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row41_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row42_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row43_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row44_col13{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row45_col13{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row46_col13{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row47_col13{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row48_col13{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row49_col13{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row50_col13,#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row51_col13{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row52_col13{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row53_col13{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row54_col13{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row55_col13{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row56_col13{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row57_col13{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_bfa402ca_ebba_11ea_b282_fbe62726ba11row58_col13{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_bfa402ca_ebba_11ea_b282_fbe62726ba11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >Min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >Max</th>        <th class="col_heading level0 col8" >Skew</th>        <th class="col_heading level0 col9" >Kurt</th>        <th class="col_heading level0 col10" >% Missing</th>        <th class="col_heading level0 col11" >% Zero</th>        <th class="col_heading level0 col12" >Nuniques</th>        <th class="col_heading level0 col13" >Corr</th>    </tr></thead><tbody>
#                 <tr>

# %% [markdown]
# Here we can select a bunch of highly skewed low correlated variables to dismiss:
#
#     * Utilities
#     * Land Slope
#     * Street
#     * Condition2
#     * PoolQC
#     * MiscFeature
#     * RoofMatl
#     * Functional
#
# Amongst the new bivariates we can dismiss:
#
#     * 'Overall'
#
# And we should keep:
#
#     * 'Conditions' instead of Condition1 and 2
#     * 'Roof' instead of 'RoofStyle' and 'RoofMtl'
#     * 'Exterior' instead of 'Exterior1st' and 'Exterior2nd'
#     * 'External' instead of 'ExternalQual' and 'ExternalCond'
#     * 'Basement' instead of 'BasementQual' and 'BasementCond'
#     * 'BasementFin' instead of 'BasementFinType1' and 'BasementFinType2'
#     * 'Garage' instead of 'GarageQual' and 'GarageCond'
#     * 'GarageTF' instead of 'GarageType' and 'GarageFinish'
#     * 'HeatingCond' intead of 'HeatingQC' and 'Heating'
#     * 'Sale' instead of 'SaleType' and SaleCond'
#     * 'Lot' instead of 'LotShape' and 'LotConfig'
#
# Let's add the first list to the dismiss list. The rest of the features we'll have to dismiss them after having created the bivariate ones, so we'll just make a dictionary of bivariates to keep track of this.

# %%
dismiss.extend(['Utilities', 'LandSlope', 'Street', 'PoolQC', 'MiscFeature', 'Functional'])
catBivs = {'Conditions': ('Condition1', 'Condition2'),
           'Roof': ('RoofStyle', 'RoofMatl'),
           'Exterior': ('Exterior1st', 'Exterior2nd'),
           'External':('ExterQual','ExterCond'),
           'Basement':('BsmtQual','BsmtCond'),
           'BasementFin': ('BsmtFinType1', 'BsmtFinType2'),
           'Sale':('SaleType','SaleCondition'),
           'Garage': ('GarageQual', 'GarageCond'),
           'GarageTF': ('GarageType', 'GarageFinish'),
           'HeatingCond': ('Heating', 'HeatingQC'),
           'Lot': ('LotShape', 'LotConfig')}

# %% [markdown]
# ## Numerical bivariates
#
# Let's also check if some numerical bivariates gives us better skew and correlation values

# %%
train['LotFrontageOverArea'] = train['LotFrontage'] * train['LotArea']
train['YearsBTWbuiltAndRemod'] = train['YearRemodAdd'] * train['YearBuilt']
train['YearsBTWbuiltAndSold'] = train['YrSold'] * train['YearBuilt']
train['YearsBTWRemodAndSold'] = train['YrSold'] *  train['YearRemodAdd']
# train['YearBuilt2'] = np.power(train['YearBuilt'], 2)
train['RemodAfter1984'] = (train['YearRemodAdd'] >= 1984).astype(int)
train['BsmtUnfPCT'] = train['BsmtUnfSF'] * train['TotalBsmtSF']
train['2ndFlr'] = (train['2ndFlrSF'] > 0).astype(int)
train['GrOverLotArea'] = train['GrLivArea'] * train['LotArea']
train['LowQualFin'] = (train['LowQualFinSF'] > 0).astype(int)
# train['YearsBuiltToday'] = 2020 - train['YearBuilt']
# train['YearsRemodToday'] = 2020 - train['YearRemodAdd']
# train['YearsSoldToday'] = 2020 - train['YrSold']

nums = [col for col in meta_num if col not in dismiss]
nums.extend(['LotFrontageOverArea', 'YearsBTWbuiltAndRemod', 'YearsBTWbuiltAndSold', 'YearsBTWRemodAndSold', 
            'RemodAfter1984', 'BsmtUnfPCT', '2ndFlr', 'GrOverLotArea', 'LowQualFin'])
#,
#            'YearsBuiltToday', 'YearsRemodToday','YearsSoldToday' ])

# %%
df_numBivsInfo = tab.numTable(train[nums], 'SalePrice')
df_numBivsInfo.style.background_gradient(subset=['Corr'])
# Out:
# <style  type="text/css" >
# #T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col13{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col13{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row2_col13{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row3_col13{
#             background-color:  #2383ba;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row4_col13,#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row5_col13{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row6_col13{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row7_col13{
#             background-color:  #3991c1;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row8_col13{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row9_col13{
#             background-color:  #3f93c2;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row10_col13{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row11_col13{
#             background-color:  #4a98c5;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row12_col13{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row13_col13{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row14_col13{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row15_col13{
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row16_col13{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row17_col13{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row18_col13{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row19_col13{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row20_col13{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row21_col13{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row22_col13{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row23_col13{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row24_col13{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row25_col13,#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row26_col13{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row27_col13{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row28_col13{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row29_col13{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row30_col13{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row31_col13{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row32_col13{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row33_col13{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_bff9c84a_ebba_11ea_8745_fbe62726ba11row34_col13{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Mean</th>        <th class="col_heading level0 col2" >Std</th>        <th class="col_heading level0 col3" >Min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >Max</th>        <th class="col_heading level0 col8" >Skew</th>        <th class="col_heading level0 col9" >Kurt</th>        <th class="col_heading level0 col10" >% Missing</th>        <th class="col_heading level0 col11" >% Zero</th>        <th class="col_heading level0 col12" >Nuniques</th>        <th class="col_heading level0 col13" >Corr</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11level0_row0" class="row_heading level0 row0" >SalePrice</th>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col0" class="data row0 col0" >1457.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col1" class="data row0 col1" >12.023753</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col2" class="data row0 col2" >0.399733</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col3" class="data row0 col3" >10.460242</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col4" class="data row0 col4" >11.774520</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col5" class="data row0 col5" >12.001505</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col6" class="data row0 col6" >12.273731</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col7" class="data row0 col7" >13.534473</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col8" class="data row0 col8" >0.123000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col9" class="data row0 col9" >0.806498</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col10" class="data row0 col10" >0.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col11" class="data row0 col11" >0.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col12" class="data row0 col12" >662</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row0_col13" class="data row0 col13" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11level0_row1" class="row_heading level0 row1" >GrLivArea</th>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col0" class="data row1 col0" >1457.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col1" class="data row1 col1" >1510.082361</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col2" class="data row1 col2" >507.841835</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col3" class="data row1 col3" >334.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col4" class="data row1 col4" >1128.000000</td>
#                         <td id="T_bff9c84a_ebba_11ea_8745_fbe62726ba11row1_col5" cl

# %% [markdown]
# There seems to be a difference in price behaviour with properties remodeled before 1984 https://www.clevelandfed.org/en/newsroom-and-events/publications/economic-commentary/economic-commentary-archives/1984-economic-commentaries/ec-19840507-the-economy-in-1984-industry-perspectives.aspx
#
# We can dismiss LowQualFin, and let's check how correlated are the rest of the features

# %%
corr_list = train[nums].corr().abs().unstack().sort_values(kind="quicksort", ascending=False)
corr_list[corr_list<1].head(25)
# Out:
# YearsBTWbuiltAndSold   YearBuilt                0.999066
# YearBuilt              YearsBTWbuiltAndSold     0.999066
# YearsBTWRemodAndSold   YearRemodAdd             0.997992
# YearRemodAdd           YearsBTWRemodAndSold     0.997992
# GrOverLotArea          LotArea                  0.952262
# LotArea                GrOverLotArea            0.952262
# LotFrontageOverArea    LotArea                  0.940675
# LotArea                LotFrontageOverArea      0.940675
# YearsBTWbuiltAndRemod  YearBuilt                0.932806
# YearBuilt              YearsBTWbuiltAndRemod    0.932806
# YearsBTWbuiltAndRemod  YearsBTWbuiltAndSold     0.932763
# YearsBTWbuiltAndSold   YearsBTWbuiltAndRemod    0.932763
# BsmtUnfSF              BsmtUnfPCT               0.914794
# BsmtUnfPCT             BsmtUnfSF                0.914794
# YearRemodAdd           RemodAfter1984           0.913870
# RemodAfter1984         YearRemodAdd             0.913870
# 2ndFlrSF               2ndFlr                   0.911899
# 2ndFlr                 2ndFlrSF                 0.911899
# RemodAfter1984         YearsBTWRemodAndSold     0.911302
# YearsBTWRemodAndSold   RemodAfter1984           0.911302
# GarageArea             GarageCars               0.887308
# GarageCars             GarageArea               0.887308
# GrOverLotArea          LotFrontageOverArea      0.881338
# LotFrontageOverArea    GrOverLotArea            0.881338
# YearRemodAdd           YearsBTWbuiltAndRemod    0.843055
# dtype: float64

# %% [markdown]
# We'll dismiss YearsBTWbuiltAndSold and YearsBTWRemodAndSold since they are highly correlated with YearBuilt and YearRemodAdd.
# GrOverLotArea and LotFrontageOverArea are higly skewed we'll try taking logs same goes for BsmtUnfPCT but in this case we have zeros, so we can't apply log

# %%
np.log(train['GrOverLotArea']).skew()
# Out:
# -0.046767114158139604

# %%
np.log(train['LotFrontageOverArea']).skew()
# Out:
# -1.1710738225515775

# %% [markdown]
# Let's make a dictionary of number bivariates

# %%
numBivMult = {'LotFrontageOverArea':('LotFrontage','LotArea'),
              'YearsBTWbuiltAndRemod':('YearRemodAdd','YearBuilt'),
              'BsmtUnfPCT': ('BsmtUnfSF','TotalBsmtSF'),
              'GrOverLotArea':('GrLivArea','LotArea')}

numBivBool = {'RemodAfter1984':('YearRemodAdd', 1983),
              '2ndFlr': ('2ndFlrSF', 0),
              'LowQualFin':('LowQualFinSF', 0)}

skewed.extend(['GrOverLotArea', 'LotFrontageOverArea'])

# %% [markdown]
# # CONCLUSION

# %%
dismiss
# Out:
# ['EnclosedPorch',
#  'LowQualFinSF',
#  'MiscVal',
#  'BsmtHalfBath',
#  'BsmtFinSF2',
#  '3SsnPorch',
#  'Pool Area',
#  'ScreenPorch',
#  'Kitchen',
#  'PoolQC',
#  'MiscFeature',
#  'Alley',
#  'Fence',
#  'GarageQual',
#  'GarageCond',
#  'Utilities',
#  'LandSlope',
#  'Street',
#  'PoolQC',
#  'MiscFeature',
#  'Functional']

# %%
outliers
# Out:
# [1299, 524, 935]

# %%
catBivs
# Out:
# {'Conditions': ('Condition1', 'Condition2'),
#  'Roof': ('RoofStyle', 'RoofMatl'),
#  'Exterior': ('Exterior1st', 'Exterior2nd'),
#  'External': ('ExterQual', 'ExterCond'),
#  'Basement': ('BsmtQual', 'BsmtCond'),
#  'BasementFin': ('BsmtFinType1', 'BsmtFinType2'),
#  'Sale': ('SaleType', 'SaleCondition'),
#  'Garage': ('GarageQual', 'GarageCond'),
#  'GarageTF': ('GarageType', 'GarageFinish'),
#  'HeatingCond': ('Heating', 'HeatingQC'),
#  'Lot': ('LotShape', 'LotConfig')}

# %%
numBivMult
# Out:
# {'LotFrontageOverArea': ('LotFrontage', 'LotArea'),
#  'YearsBTWbuiltAndRemod': ('YearRemodAdd', 'YearBuilt'),
#  'BsmtUnfPCT': ('BsmtUnfSF', 'TotalBsmtSF'),
#  'GrOverLotArea': ('GrLivArea', 'LotArea')}

# %%
numBivBool
# Out:
# {'RemodAfter1984': ('YearRemodAdd', 1983),
#  '2ndFlr': ('2ndFlrSF', 0),
#  'LowQualFin': ('LowQualFinSF', 0)}

# %%
skewed
# Out:
# ['MasVnrArea',
#  'LotFrontage',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'LotArea',
#  'GrOverLotArea',
#  'LotFrontageOverArea']

# %%
tab.numTable(train[skewed + ['SalePrice']], 'SalePrice')
# Out:
#                       Count          Mean           Std            Min  \
# SalePrice            1457.0  1.202375e+01  3.997333e-01      10.460242
# MasVnrArea           1457.0  1.028243e+02  1.789900e+02       0.000000
# GrOverLotArea        1457.0  1.693728e+07  2.102461e+07  930510.000000
# LotFrontage          1198.0  6.959432e+01  2.212229e+01      21.000000
# WoodDeckSF           1457.0  9.414894e+01  1.253688e+02       0.000000
# OpenPorchSF          1457.0  4.627728e+01  6.532411e+01       0.000000
# LotFrontageOverArea  1198.0  7.527303e+05  1.042140e+06   31017.000000
# LotArea              1457.0  1.044814e+04  9.852282e+03    1300.000000
#
#                               25%           50%           75%           Max  \
# SalePrice            1.177452e+01  1.200151e+01  1.227373e+01  1.353447e+01
# MasVnrArea           0.000000e+00  0.000000e+00  1.640000e+02  1.600000e+03
# GrOverLotArea        8.643348e+06  1.339800e+07  2.011500e+07  4.382388e+08
# LotFrontage          5.900000e+01  6.900000e+01  8.000000e+01  1.820000e+02
# WoodDeckSF           0.000000e+00  0.000000e+00  1.680000e+02  8.570000e+02
# OpenPorchSF          0.000000e+00  2.500000e+01  6.800000e+01  5.470000e+02
# LotFrontageOverArea  4.491520e+05  6.394800e+05  8.982862e+05  3.228675e+07
# LotArea              7.540000e+03  9.473000e+03  1.160000e+04  2.152450e+05
#
#                           Skew        Kurt  % Missing  % Zero  Nuniques  \
# SalePrice             0.123000    0.806498       0.00    0.00       662
# MasVnrArea            2.694112   10.424316       0.00   59.03       326
# GrOverLotArea        11.079948  177.510995       0.00    0.00      1416
# LotFrontage           0.697732    2.362428      17.78    0.00       109
# WoodDeckSF            1.544917    3.003056       0.00   52.16       274
# OpenPorchSF           2.339021    8.471638       0.00   44.96       200
# LotFrontageOverArea  23.475771  701.735895      17.78    0.00       938
# LotArea              12.609035  214.403479       0.00    0.00      1070
#
#                          Corr
# SalePrice            1.000000
# MasVnrArea           0.433878
# GrOverLotArea        0.406664
# LotFrontage          0.383015
# WoodDeckSF           0.334896
# OpenPorchSF          0.325822
# LotFrontageOverArea  0.260961
# LotArea              0.259776

# %%
np.log(train['LotArea']).skew()
# Out:
# -0.185330506218561

# %%
np.log(train['LotFrontage']).skew()
# Out:
# -0.9342734612645425

# %%
train['LotFrontageOverArea'] = np.log(train['LotArea']) * np.log(train['LotFrontage'])
train[['LotFrontageOverArea']].skew()
# Out:
# LotFrontageOverArea   -0.864588
# dtype: float64

# %%
np.cbrt(train['MasVnrArea']).skew()
# Out:
# 0.6867119501528206

# %%
np.cbrt(train['OpenPorchSF']).skew()
# Out:
# 0.17255144010216086

# %%
np.cbrt(train['WoodDeckSF']).skew()
# Out:
# 0.2752423770771553

# %%
len(train.columns) - len(dismiss) - 20
# Out:
# 60

# %% [markdown]
# After processing we would have 61 features remaining

# %%
train['GrOverLotArea'] = np.log(train['LotArea']) * train['GrLivArea']
train[['GrOverLotArea']].skew()
# Out:
# GrOverLotArea    1.132278
# dtype: float64

# %%
np.log(train['GrOverLotArea']).skew()
# Out:
# -0.0424224832095246

# %%
np.log(train['GrOverLotArea']).kurt()
# Out:
# 0.10154018812414822
